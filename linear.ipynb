# %%
import pandas as pd
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from dataset import get_dataset

# %%
points_data_set, _ = get_dataset()

# %%
df = pd.DataFrame.from_dict(points_data_set, orient='index')
df = df.drop(columns=['first_name', 'last_name', 'name'])
df[df['id'] == 387]
# Out:
#     team   id position                                      GW77  \
# 387  MUN  387      DEF  {'diff': 2, 'points': 12, 'team': 'FUL'}
#
#                                          GW78  \
# 387  {'diff': 4, 'points': -2, 'team': 'LIV'}
#
#                                         GW80  \
# 387  {'diff': 2, 'points': 0, 'team': 'NFO'}
#
#                                         GW81  \
# 387  {'diff': 2, 'points': 9, 'team': 'IPS'}
#
#                                         GW82  \
# 387  {'diff': 2, 'points': 9, 'team': 'NEW'}
#
#                                         GW83  \
# 387  {'diff': 3, 'points': 1, 'team': 'AVL'}
#
#                                         GW84  ... GW299 GW195 GW107 GW217  \
# 387  {'diff': 3, 'points': 2, 'team': 'WOL'}  ...   NaN   NaN   NaN   NaN
#
#     GW223 GW224 GW190 GW229 GW218 GW304
# 387   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 230 columns]

# %%
gw_columns = [col for col in df.columns if col.startswith('GW')]
for col in gw_columns:
    df[col] = df[col].apply(lambda x: x['points'] if pd.notnull(x) else None)
df_melted = df.melt(id_vars=['team', 'position', 'id'],
                    value_vars=gw_columns,
                    var_name='GW',
                    value_name='Points')
df_melted.dropna(subset=['Points'], inplace=True)
df_melted.head(1)
# Out:
#   team position   id    GW  Points
# 0  MUN      DEF  387  GW77    12.0

# %%
df_melted['GW'] = df_melted['GW'].str.replace('GW', '').astype(int)
df_melted = pd.get_dummies(df_melted, columns=['team', 'position'])
df_melted.head(1)
# Out:
#     id  GW  Points  team_ARS  team_AVL  team_BHA  team_BOU  team_BRE  \
# 0  387  77    12.0     False     False     False     False     False
#
#    team_CHE  team_CRY  ...  team_NEW  team_NFO  team_SOU  team_TOT  team_WHU  \
# 0     False     False  ...     False     False     False     False     False
#
#    team_WOL  position_DEF  position_FWD  position_GKP  position_MID
# 0     False          True         False         False         False
#
# [1 rows x 27 columns]

# %%
df_melted['RecentFormAvg'] = df_melted.groupby('id')['Points'].rolling(window=3, min_periods=1).mean().reset_index(0,drop=True)
df_melted.head(1)
# Out:
#     id  GW  Points  team_ARS  team_AVL  team_BHA  team_BOU  team_BRE  \
# 0  387  77    12.0     False     False     False     False     False
#
#    team_CHE  team_CRY  ...  team_NFO  team_SOU  team_TOT  team_WHU  team_WOL  \
# 0     False     False  ...     False     False     False     False     False
#
#    position_DEF  position_FWD  position_GKP  position_MID  RecentFormAvg
# 0          True         False         False         False           12.0
#
# [1 rows x 28 columns]

# %%
df_melted['HistoricalPerformanceAvg'] = df_melted.groupby('id')['Points'].expanding().mean().reset_index(0,drop=True)
df_melted.head()
# Out:
#     id  GW  Points  team_ARS  team_AVL  team_BHA  team_BOU  team_BRE  \
# 0  387  77    12.0     False     False     False     False     False
# 1  216  77     3.0     False     False     False     False     False
# 2   80  77     6.0     False     False     False      True     False
# 3  468  77    11.0     False     False     False     False     False
# 4  309  77     7.0     False     False     False     False     False
#
#    team_CHE  team_CRY  ...  team_SOU  team_TOT  team_WHU  team_WOL  \
# 0     False     False  ...     False     False     False     False
# 1     False     False  ...     False     False     False     False
# 2     False     False  ...     False     False     False     False
# 3     False     False  ...      True     False     False     False
# 4     False     False  ...     False     False     False     False
#
#    position_DEF  position_FWD  position_GKP  position_MID  RecentFormAvg  \
# 0          True         False         False         False           12.0
# 1         False         False         False          True            3.0
# 2          True         False         False         False            6.0
# 3         False         False          True         False           11.0
# 4         False         False          True         False            7.0
#
#    HistoricalPerformanceAvg
# 0                      12.0
# 1                       3.0
# 2                       6.0
# 3                      11.0
# 4                       7.0
#
# [5 rows x 29 columns]

# %%
df_melted = df_melted.sort_values(by=['id', 'GW'])
df = df_melted[df_melted['GW'] == df_melted['GW'].max()]

# %%
df = df.drop(columns=['GW'])
df.head()
# Out:
#        id  Points  team_ARS  team_AVL  team_BHA  team_BOU  team_BRE  team_CHE  \
# 72866   1     1.0      True     False     False     False     False     False
# 73153   2     1.0      True     False     False     False     False     False
# 73007   3     6.0      True     False     False     False     False     False
# 73256   5     0.0      True     False     False     False     False     False
# 73138   8     2.0      True     False     False     False     False     False
#
#        team_CRY  team_EVE  ...  team_SOU  team_TOT  team_WHU  team_WOL  \
# 72866     False     False  ...     False     False     False     False
# 73153     False     False  ...     False     False     False     False
# 73007     False     False  ...     False     False     False     False
# 73256     False     False  ...     False     False     False     False
# 73138     False     False  ...     False     False     False     False
#
#        position_DEF  position_FWD  position_GKP  position_MID  RecentFormAvg  \
# 72866         False          True         False         False       2.000000
# 73153          True         False         False         False       5.000000
# 73007         False          True         False         False       5.666667
# 73256          True         False         False         False       0.000000
# 73138         False         False         False          True       1.333333
#
#        HistoricalPerformanceAvg
# 72866                  3.689076
# 73153                  3.783784
# 73007                  3.684932
# 73256                  0.000000
# 73138                  3.540541
#
# [5 rows x 28 columns]

# %%
X = df.drop(columns=['Points'])
y = df['Points']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.22038564600227595
