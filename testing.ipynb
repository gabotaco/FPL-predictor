# %%
import pandas as pd
from sklearn.metrics import r2_score

# %%
from dataset import get_dataset
from game_information import MIN_GAMES, MIN_SEASON_PPG, SEASON_LENGTH, MIN_SEASON_GAME_PERCENTAGE
from ai import do_arima, do_lstm, MAX_DIFF

# %%
BUGGED_PLAYERS = []

# %%
points_data_set, _ = get_dataset()

# %%
points_df = pd.DataFrame.from_dict(points_data_set, orient='index')
points_df.head()
# Out:
#     first_name      last_name         name team   id position  \
# 387      Aaron    Wan-Bissaka  Wan-Bissaka  MUN  387      DEF
# 216  Abdoulaye       Doucouré   A.Doucoure  EVE  216      MID
# 80        Adam          Smith        Smith  BOU   80      DEF
# 468       Alex       McCarthy     McCarthy  SOU  468      GKP
# 309    Alisson  Ramses Becker     A.Becker  LIV  309      GKP
#
#                                          GW77  \
# 387  {'diff': 2, 'points': 12, 'team': 'FUL'}
# 216   {'diff': 2, 'points': 3, 'team': 'BOU'}
# 80    {'diff': 2, 'points': 6, 'team': 'BHA'}
# 468  {'diff': 2, 'points': 11, 'team': 'BRE'}
# 309   {'diff': 3, 'points': 7, 'team': 'WHU'}
#
#                                          GW78  \
# 387  {'diff': 4, 'points': -2, 'team': 'LIV'}
# 216   {'diff': 3, 'points': 6, 'team': 'BRE'}
# 80    {'diff': 3, 'points': 2, 'team': 'WHU'}
# 468   {'diff': 3, 'points': 2, 'team': 'EVE'}
# 309   {'diff': 2, 'points': 6, 'team': 'CRY'}
#
#                                         GW80  \
# 387  {'diff': 2, 'points': 0, 'team': 'NFO'}
# 216  {'diff': 4, 'points': 0, 'team': 'SOU'}
# 80   {'diff': 4, 'points': 2, 'team': 'CHE'}
# 468  {'diff': 2, 'points': 8, 'team': 'CRY'}
# 309  {'diff': 3, 'points': 3, 'team': 'LEI'}
#
#                                         GW81  ...  \
# 387  {'diff': 2, 'points': 9, 'team': 'IPS'}  ...
# 216  {'diff': 4, 'points': 8, 'team': 'MUN'}  ...
# 80   {'diff': 3, 'points': 7, 'team': 'LEI'}  ...
# 468  {'diff': 2, 'points': 0, 'team': 'BOU'}  ...
# 309  {'diff': 4, 'points': 2, 'team': 'SOU'}  ...
#
#                                        GW299  \
# 387                                      NaN
# 216                                      NaN
# 80   {'diff': 3, 'points': 0, 'team': 'IPS'}
# 468                                      NaN
# 309                                      NaN
#
#                                        GW195  \
# 387                                      NaN
# 216                                      NaN
# 80                                       NaN
# 468  {'diff': 4, 'points': 5, 'team': 'FUL'}
# 309                                      NaN
#
#                                        GW107  \
# 387                                      NaN
# 216                                      NaN
# 80                                       NaN
# 468                                      NaN
# 309  {'diff': 2, 'points': 2, 'team': 'FUL'}
#
#                                        GW217  \
# 387                                      NaN
# 216                                      NaN
# 80                                       NaN
# 468                                      NaN
# 309  {'diff': 4, 'points': 2, 'team': 'SOU'}
#
#                                        GW223  \
# 387                                      NaN
# 216                                      NaN
# 80                                       NaN
# 468                                      NaN
# 309  {'diff': 2, 'points': 6, 'team': 'FUL'}
#
#                                         GW224 GW190 GW229 GW218 GW304
# 387                                       NaN   NaN   NaN   NaN   NaN
# 216                                       NaN   NaN   NaN   NaN   NaN
# 80                                        NaN   NaN   NaN   NaN   NaN
# 468                                       NaN   NaN   NaN   NaN   NaN
# 309  {'diff': 2, 'points': 10, 'team': 'BHA'}   NaN   NaN   NaN   NaN
#
# [5 rows x 233 columns]

# %%
def process_player(player_data):
    points_sum = 0
    num_games = 0
    total_games = 0
    
    gws = []
    
    for dataset, data in player_data.items():
        if not dataset.startswith('GW') or not isinstance(data, dict):
            continue
            
        total_games += 1
        gws.append(data)
        
        round_num = int(dataset.replace('GW', ''))
        beginning_round = 273
                
        if round_num >= beginning_round:
            points_sum += data['points']
            num_games += 1
            
    calibrate_by = 10
            
    if total_games - calibrate_by < MIN_GAMES or points_sum < MIN_SEASON_PPG * num_games or num_games < SEASON_LENGTH * MIN_SEASON_GAME_PERCENTAGE:
        return [], [], [], 0
    
    pred_by = []
    training_player_data = {'position': player_data['position']}
    
    for gw_num in range(0, len(gws) - calibrate_by + 1):
        training_player_data[f"GW{gw_num + 1}"] = gws[gw_num]
        
    actual_points = []
    for gw in gws[gw_num:]:
        pred_by.append(gw['diff'])
        actual_points.append(gw['points'])
        
    if sum(actual_points) < calibrate_by * MIN_SEASON_PPG:
        return [], [], [], 0
    
    if sum(actual_points) <= 0 or len(gws[:-calibrate_by]) < calibrate_by:
        return [], [], [], 0
    else:
        try:
            arima = do_arima(list(map(lambda x: x['points'], gws[:-calibrate_by])), pred_by)
            lstm = do_lstm(training_player_data, pred_by)
        except:
            return [], [], [], 0
        
        if sum(arima) != 0 and sum(lstm) != 0 and (sum(arima) / sum(lstm) > MAX_DIFF or sum(lstm) / sum(arima) > MAX_DIFF):
            return [], [], [], 0
        
        return actual_points, arima, lstm, calibrate_by

# %%
player_datas = []
arima_pred = []
lstm_pred = []
actual_val = []
calibrate_by = []

# %%
for index, player_data in points_df.iterrows():
    actual, arima, lstm, cal = process_player(player_data)
    if len(actual) > 0:
        player_datas.append(player_data)
        arima_pred.append(arima[0])
        lstm_pred.append(lstm[0])
        actual_val.append(actual[0])
        calibrate_by.append(cal)

# %%
results = pd.DataFrame()
results['player'] = player_datas
results['arima'] = arima_pred
results['lstm'] = lstm_pred
results['actual'] = actual_val
results['calibrate by'] = calibrate_by
results
# Out:
#                                                 player     arima      lstm  \
# 0    first_name     Abdoulaye
# last_name       Douco...  3.101190  2.868421
# 1    first_name     Adam
# last_name     Smith
# name  ...  2.640304  2.596128
# 2    first_name                                    ...  4.287293  3.097384
# 3    first_name                                    ...  3.265267  3.592019
# 4    first_name                                    ...  3.025000  3.027827
# ..                                                 ...       ...       ...
# 145  first_name      Joe
# last_name     Gomez
# name  ...  2.500000  2.172567
# 146  first_name                                    ...  1.857143  1.890368
# 147  first_name                                    ...  1.315789  1.010912
# 148  first_name     Rasmus
# last_name     Højlund
# na...  3.315789  2.253943
# 149  first_name                                   M...  4.217391  1.630387
#
#      actual  calibrate by
# 0         2            10
# 1         6            10
# 2        14            10
# 3         1            10
# 4         9            10
# ..      ...           ...
# 145       1            10
# 146       1            10
# 147       1            10
# 148       2            10
# 149       2            10
#
# [150 rows x 5 columns]
